# %%
Nikunj Deep Upadhyay
25070123081
Entc b1

# %%
thisset={"apple","banana","cherry", True,1,2}
print(thisset)
# Out:
# {True, 2, 'banana', 'apple', 'cherry'}

# %%
THISSET={"apple","banana","cherry"}
print("banana" in THISSET)
print("apple" in THISSET)
print("grapes" in THISSET)
THISSET.add("orange")
THISSET.add(1)
THISSET.remove("banana")
print(THISSET)
# Out:
# True
# True
# False
# {1, 'orange', 'apple', 'cherry'}

# %%
#SET OPERATIONS
A={1,2,3,4}
B={3,4,5,6}
print("Union:")

# %%
# frozenset
x=frozenset({"apple","banana","cherry"})
print(x)
# Out:
# frozenset({'apple', 'banana', 'cherry'})

# %%
LIST1=["AKRAM","SHAAD","MEHUL","YOUNUS","RAYYAN","MEHUL"]
y=set(LIST1)
print(y)
# Out:
# {'RAYYAN', 'MEHUL', 'YOUNUS', 'AKRAM', 'SHAAD'}

# %%
SHAAD={"mathematics","english","physics"}
RAYYAN={"mathematics","hindi","chemistry"}
BASHAR={" economics","accountancy","mathematics"}
t=SHAAD & RAYYAN & BASHAR
print(t)
# Out:
# {'mathematics'}

# %%
cr={"pushkar","aarav","rayyan"}
ft={"rayyan","akhil","samad"}
s=cr-ft
g=ft-cr
print(s)
print(g)
# Out:
# {'pushkar', 'aarav'}
# {'samad', 'akhil'}

# %%
ALL_STUDENTS={"TAQI","HASAN","RAYYAN","SHAAD"}
PRESENT_STUDENTS={"SHAAD","TAQI"}
ABSENT_STUDENTS=ALL_STUDENTS-PRESENT_STUDENTS
print(ABSENT_STUDENTS)
# Out:
# {'RAYYAN', 'HASAN'}

# %%
courses={"etc101","etc102","etc103"}
courses.discard("etc102")
print("updated courses:",courses)
# Out:
# updated courses: {'etc101', 'etc103'}
